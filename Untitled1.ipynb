# %%
import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"

response = requests.get(url)
if response.status_code == 200:
    html_content = response.text
else:
    print("Failed to retrieve the webpage")

# %%
# Find all book containers
books = soup.find_all('article', class_='product_pod')

for book in books:
    # Extract title
    title = book.h3.a['title']
    # Extract price
    price = book.find('p', class_='price_color').text
    # Extract availability
    availability = book.find('p', class_='instock availability').text.strip()
    
    print(f"Title: {title}")
    print(f"Price: {price}")
    print(f"Availability: {availability}")
    print('-' * 50)
# Out:
# Title: A Light in the Attic
# Price: Â£51.77
# Availability: In stock
# --------------------------------------------------
# Title: Tipping the Velvet
# Price: Â£53.74
# Availability: In stock
# --------------------------------------------------
# Title: Soumission
# Price: Â£50.10
# Availability: In stock
# --------------------------------------------------
# Title: Sharp Objects
# Price: Â£47.82
# Availability: In stock
# --------------------------------------------------
# Title: Sapiens: A Brief History of Humankind
# Price: Â£54.23
# Availability: In stock
# --------------------------------------------------
# Title: The Requiem Red
# Price: Â£22.65
# Availability: In stock
# --------------------------------------------------
# Title: The Dirty Little Secrets of Getting Your Dream Job
# Price: Â£33.34
# Availability: In stock
# --------------------------------------------------
# Title: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# ...

# %%
base_url = "https://books.toscrape.com/catalogue/page-{}.html"

for page_num in range(1, 6):  # Example: scrape first 5 pages
    url = base_url.format(page_num)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    books = soup.find_all('article', class_='product_pod')
    for book in books:
        title = book.h3.a['title']
        price = book.find('p', class_='price_color').text
        availability = book.find('p', class_='instock availability').text.strip()
        print(f"Title: {title} | Price: {price} | Availability: {availability}")
# Out:
# Title: A Light in the Attic | Price: Â£51.77 | Availability: In stock
# Title: Tipping the Velvet | Price: Â£53.74 | Availability: In stock
# Title: Soumission | Price: Â£50.10 | Availability: In stock
# Title: Sharp Objects | Price: Â£47.82 | Availability: In stock
# Title: Sapiens: A Brief History of Humankind | Price: Â£54.23 | Availability: In stock
# Title: The Requiem Red | Price: Â£22.65 | Availability: In stock
# Title: The Dirty Little Secrets of Getting Your Dream Job | Price: Â£33.34 | Availability: In stock
# Title: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull | Price: Â£17.93 | Availability: In stock
# Title: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics | Price: Â£22.60 | Availability: In stock
# Title: The Black Maria | Price: Â£52.15 | Availability: In stock
# Title: Starving Hearts (Triangular Trade Trilogy, #1) | Price: Â£13.99 | Availability: In stock
# ...

# %%
import csv

# Example scraped data: list of dictionaries
scraped_data = [
    {'Title': 'Book 1', 'Price': '£51.77', 'Availability': 'In stock'},
    {'Title': 'Book 2', 'Price': '£45.17', 'Availability': 'In stock'},
    # Add more scraped items here
]

# Specify CSV file name
filename = 'scraped_data.csv'

# Writing to CSV
with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Title', 'Price', 'Availability']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()  # Write column headers
    for data in scraped_data:
        writer.writerow(data)

print(f"Data has been written to '{filename}'")
# Out:
# Data has been written to 'scraped_data.csv'

# %%
import pandas as pd

# Example scraped data as list of dictionaries
scraped_data = [
    {'Title': 'Book 1', 'Price': '£51.77', 'Availability': 'In stock'},
    {'Title': 'Book 2', 'Price': '£45.17', 'Availability': 'In stock'},
    # Add more scraped items here
]

# Convert to DataFrame
df = pd.DataFrame(scraped_data)

# Export to CSV without the index column
df.to_csv('scraped_data.csv', index=False, encoding='utf-8')

print("Data has been saved to 'scraped_data.csv'")
# Out:
# Data has been saved to 'scraped_data.csv'

# %%
scraped_data = []

for book in books:
    title = book.h3.a['title']
    price = book.find('p', class_='price_color').text
    availability = book.find('p', class_='instock availability').text.strip()
    scraped_data.append({'Title': title, 'Price': price, 'Availability': availability})

# %%
scraped_data
# Out:
# [{'Title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'Price': 'Â£13.61',
#   'Availability': 'In stock'},
#  {'Title': 'Princess Between Worlds (Wide-Awake Princess #5)',
#   'Price': 'Â£13.34',
#   'Availability': 'In stock'},
#  {'Title': 'Pop Gun War, Volume 1: Gift',
#   'Price': 'Â£18.97',
#   'Availability': 'In stock'},
#  {'Title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   'Price': 'Â£36.28',
#   'Availability': 'In stock'},
#  {'Title': 'Patience', 'Price': 'Â£10.16', 'Availability': 'In stock'},
#  {'Title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'Price': 'Â£15.44',
#   'Availability': 'In stock'},
#  {'Title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'Price': 'Â£48.41',
#   'Availability': 'In stock'},
# ...

# %%
import pandas as pd

# Suppose scraped_data is a list of dictionaries from your scraping
scraped_data = [
    {'Title': 'Book 1', 'Price': '£51.77', 'Availability': 'In stock'},
    {'Title': 'Book 2', 'Price': '£45.17', 'Availability': 'In stock'},
    # ... more data
]

# Convert to DataFrame
df = pd.DataFrame(scraped_data)

# Export to CSV file without the index column
df.to_csv('scraped_data.csv', index=False, encoding='utf-8')

print("Data exported successfully to 'scraped_data.csv'")
# Out:
# Data exported successfully to 'scraped_data.csv'

# %%
scraped_data.csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 scraped_data.csv
#
# AttributeError: 'list' object has no attribute 'csv'

# %%
import csv

# Example scraped data: list of dictionaries
scraped_data = [
    {'Title': 'Book 1', 'Price': '£51.77', 'Availability': 'In stock'},
    {'Title': 'Book 2', 'Price': '£45.17', 'Availability': 'In stock'},
    # Add more scraped items here
]

# Specify CSV file name
filename = 'scraped_data.csv'

# Writing to CSV
with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Title', 'Price', 'Availability']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()  # Write column headers
    for data in scraped_data:
        writer.writerow(data)

print(f"Data has been written to '{filename}'")
# Out:
# Data has been written to 'scraped_data.csv'
